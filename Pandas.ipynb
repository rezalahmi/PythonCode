# %%
import pandas as pd

# %%
#Read a comma-separated values (csv) file into DataFrame.
df_food = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\7. Data Analytics (Pandas)\2.1 Food Orders.csv')

# %%
#Return the first n rows.
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item
# 0         2           19.99
# 1         3            8.99
# 2         3            4.99
# 3         3            6.99
# 4         3           19.99

# %%
df_food.head(10)
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
# 5           1006           C   Oasis Seafood      Cod Fingers   Monday
# 6           1007           C   BBQ Pit Kings             Ribs   Monday
# 7           1008           C   BBQ Pit Kings   Smoked Chicken  Tuesday
# 8           1009           C   BBQ Pit Kings   Smoked Sausage  Tuesday
# 9           1010           C  Chicken Roller   Bucket Special  Tuesday
#
#    Quantity  Price Per Item
# 0         2           19.99
# 1         3            8.99
# 2         3            4.99
# 3         3            6.99
# 4         3           19.99
# 5         1            5.99
# 6         3           11.99
# 7         1           12.99
# 8         1            7.99
# 9         2           15.99

# %%
#Get the number of rows: len(df)
len(df_food)
# Out:
# 55

# %%
#Get the number of columns: len(df.columns)
len(df_food.columns)
# Out:
# 7

# %%
#Get the number of rows and columns: df.shape
df_food.shape
# Out:
# (55, 7)

# %%
#The DataFrames object has a method called info(), that gives you more information about the data set.
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Food Order ID    55 non-null     int64
#  1   Customer ID      55 non-null     object
#  2   Restaurant Name  55 non-null     object
#  3   Meal Ordered     55 non-null     object
#  4   Day              55 non-null     object
#  5   Quantity         55 non-null     int64
#  6   Price Per Item   55 non-null     float64
#  7   Total Amount     55 non-null     float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.6+ KB

# %%
#Descriptive statistics include those that summarize the central tendency, 
#dispersion and shape of a dataset’s distribution, excluding NaN values.
df_food.describe()
# Out:
#        Food Order ID   Quantity  Price Per Item
# count       55.00000  55.000000       55.000000
# mean      1028.00000   1.890909       10.426364
# std         16.02082   0.831614        5.449307
# min       1001.00000   1.000000        3.990000
# 25%       1014.50000   1.000000        4.990000
# 50%       1028.00000   2.000000        8.990000
# 75%       1041.50000   3.000000       12.990000
# max       1055.00000   3.000000       19.990000

# %%
df_food.describe(include='all')
# Out:
#         Food Order ID Customer ID Restaurant Name Meal Ordered     Day  \
# count        55.00000          55              55           55      55
# unique            NaN          13               4           12       7
# top               NaN           I   BBQ Pit Kings         Ribs  Monday
# freq              NaN           7              16            8      13
# mean       1028.00000         NaN             NaN          NaN     NaN
# std          16.02082         NaN             NaN          NaN     NaN
# min        1001.00000         NaN             NaN          NaN     NaN
# 25%        1014.50000         NaN             NaN          NaN     NaN
# 50%        1028.00000         NaN             NaN          NaN     NaN
# 75%        1041.50000         NaN             NaN          NaN     NaN
# max        1055.00000         NaN             NaN          NaN     NaN
#
#          Quantity  Price Per Item
# count   55.000000       55.000000
# unique        NaN             NaN
# top           NaN             NaN
# freq          NaN             NaN
# mean     1.890909       10.426364
# std      0.831614        5.449307
# min      1.000000        3.990000
# 25%      1.000000        4.990000
# 50%      2.000000        8.990000
# 75%      3.000000       12.990000
# max      3.000000       19.990000

# %%
#Return the dtypes in the DataFrame.
df_food.dtypes
# Out:
# Food Order ID        int64
# Customer ID         object
# Restaurant Name     object
# Meal Ordered        object
# Day                 object
# Quantity             int64
# Price Per Item     float64
# dtype: object

# %%
#Cast a pandas object to a specified dtype dtype.
df_string = df_food.astype('object')
df_string.dtypes
# Out:
# Food Order ID      object
# Customer ID        object
# Restaurant Name    object
# Meal Ordered       object
# Day                object
# Quantity           object
# Price Per Item     object
# dtype: object

# %%
df_float = df_string.astype({'Food Order ID':'int64','Quantity':'int64','Price Per Item':'float'})
df_float.dtypes
# Out:
# Food Order ID        int64
# Customer ID         object
# Restaurant Name     object
# Meal Ordered        object
# Day                 object
# Quantity             int64
# Price Per Item     float64
# dtype: object

# %%
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item
# 0         2           19.99
# 1         3            8.99
# 2         3            4.99
# 3         3            6.99
# 4         3           19.99

# %%
df_food['Total Amount'] = df_food['Quantity'] * df_food['Price Per Item']

# %%
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount
# 0         2           19.99         39.98
# 1         3            8.99         26.97
# 2         3            4.99         14.97
# 3         3            6.99         20.97
# 4         3           19.99         59.97

# %%
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item
# 0         2           19.99
# 1         3            8.99
# 2         3            4.99
# 3         3            6.99
# 4         3           19.99

# %%
df_food[['Food Order ID','Customer ID','Restaurant Name','Meal Ordered','Quantity','Price Per Item']]\
.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered  Quantity  \
# 0           1001           A   Oasis Seafood  Seafood Platter         2
# 1           1002           A   Oasis Seafood         Scallops         3
# 2           1003           A      Green Fuel          Falafel         3
# 3           1004           B      Green Fuel    Mixed Lentils         3
# 4           1005           B   Oasis Seafood  Seafood Platter         3
#
#    Price Per Item
# 0           19.99
# 1            8.99
# 2            4.99
# 3            6.99
# 4           19.99

# %%
df_food['totla amount'] = df_food['Quantity'] * df_food['Price Per Item']
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  totla amount
# 0         2           19.99         39.98
# 1         3            8.99         26.97
# 2         3            4.99         14.97
# 3         3            6.99         20.97
# 4         3           19.99         59.97

# %%
#if you want to determined the row situation which saticfy condition or not, use filter like this
df_food['Restaurant Name'] == "Oasis Seafood"
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31     True
# 32     True
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# 50     True
# 51    False
# 52     True
# 53    False
# 54    False
# Name: Restaurant Name, dtype: bool

# %%
df_food[df_food['Restaurant Name'] == "Oasis Seafood"]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 0            1001           A   Oasis Seafood  Seafood Platter    Tuesday
# 1            1002           A   Oasis Seafood         Scallops     Friday
# 4            1005           B   Oasis Seafood  Seafood Platter    Tuesday
# 5            1006           C   Oasis Seafood      Cod Fingers     Monday
# 12           1013           E   Oasis Seafood  Seafood Platter     Friday
# 24           1025           G   Oasis Seafood  Seafood Platter     Friday
# 27           1028           H   Oasis Seafood      Cod Fingers     Monday
# 31           1032           H   Oasis Seafood  Seafood Platter   Saturday
# 32           1033           I   Oasis Seafood  Seafood Platter     Sunday
# 34           1035           I   Oasis Seafood         Scallops     Monday
# 41           1042           J   Oasis Seafood         Scallops     Friday
# 49           1050           L   Oasis Seafood  Seafood Platter     Monday
# 50           1051           L   Oasis Seafood      Cod Fingers     Monday
# 52           1053           M   Oasis Seafood  Seafood Platter  Wednesday
#
#     Quantity  Price Per Item  totla amount
# 0          2           19.99         39.98
# 1          3            8.99         26.97
# 4          3           19.99         59.97
# 5          1            5.99          5.99
# 12         3           19.99         59.97
# 24         2           19.99         39.98
# 27         3            5.99         17.97
# 31         2           19.99         39.98
# 32         2           19.99         39.98
# 34         1            8.99          8.99
# 41         1            8.99          8.99
# 49         2           19.99         39.98
# 50         3            5.99         17.97
# 52         2           19.99         39.98

# %%
df_food[df_food['totla amount'] > 50]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 4            1005           B   Oasis Seafood  Seafood Platter  Tuesday
# 12           1013           E   Oasis Seafood  Seafood Platter   Friday
#
#     Quantity  Price Per Item  totla amount
# 4          3           19.99         59.97
# 12         3           19.99         59.97

# %%
#you can combine filter with logical operator & , |
df_food[(df_food['Quantity']>2)|(df_food['totla amount']>40)]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 1            1002           A   Oasis Seafood         Scallops     Friday
# 2            1003           A      Green Fuel          Falafel     Friday
# 3            1004           B      Green Fuel    Mixed Lentils     Friday
# 4            1005           B   Oasis Seafood  Seafood Platter    Tuesday
# 6            1007           C   BBQ Pit Kings             Ribs     Monday
# 12           1013           E   Oasis Seafood  Seafood Platter     Friday
# 16           1017           F   BBQ Pit Kings   Smoked Chicken     Monday
# 17           1018           F      Green Fuel       Green Poke   Saturday
# 18           1019           F  Chicken Roller   Bucket Special    Tuesday
# 23           1024           G  Chicken Roller          Tenders     Sunday
# 27           1028           H   Oasis Seafood      Cod Fingers     Monday
# 33           1034           I   BBQ Pit Kings   Smoked Chicken   Thursday
# 42           1043           K   BBQ Pit Kings   Smoked Chicken   Saturday
# 50           1051           L   Oasis Seafood      Cod Fingers     Monday
# 51           1052           L   BBQ Pit Kings             Ribs  Wednesday
# 54           1055           M      Green Fuel    Mixed Lentils  Wednesday
#
#     Quantity  Price Per Item  totla amount
# 1          3            8.99         26.97
# 2          3            4.99         14.97
# 3          3            6.99         20.97
# 4          3           19.99         59.97
# 6          3           11.99         35.97
# 12         3           19.99         59.97
# 16         3           12.99         38.97
# 17         3            8.99         26.97
# 18         3           15.99         47.97
# 23         3            4.99         14.97
# 27         3            5.99         17.97
# 33         3           12.99         38.97
# 42         3           12.99         38.97
# 50         3            5.99         17.97
# 51         3           11.99         35.97
# 54         3            6.99         20.97

# %%
df_food[(df_food['Quantity']>2)&(df_food['totla amount']>40)]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 4            1005           B   Oasis Seafood  Seafood Platter  Tuesday
# 12           1013           E   Oasis Seafood  Seafood Platter   Friday
# 18           1019           F  Chicken Roller   Bucket Special  Tuesday
#
#     Quantity  Price Per Item  totla amount
# 4          3           19.99         59.97
# 12         3           19.99         59.97
# 18         3           15.99         47.97

# %%
df_food[((df_food['Quantity']>2)|(df_food['totla amount']>40))&(df_food['Day']=="Friday")]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered     Day  \
# 1            1002           A   Oasis Seafood         Scallops  Friday
# 2            1003           A      Green Fuel          Falafel  Friday
# 3            1004           B      Green Fuel    Mixed Lentils  Friday
# 12           1013           E   Oasis Seafood  Seafood Platter  Friday
#
#     Quantity  Price Per Item  totla amount
# 1          3            8.99         26.97
# 2          3            4.99         14.97
# 3          3            6.99         20.97
# 12         3           19.99         59.97

# %%
#Whether each element in the DataFrame is contained in values.
df_food[df_food['Customer ID'].isin(['A','B'])]
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  totla amount
# 0         2           19.99         39.98
# 1         3            8.99         26.97
# 2         3            4.99         14.97
# 3         3            6.99         20.97
# 4         3           19.99         59.97

# %%
df_food[(df_food['Customer ID'].isin(['A','B']))&(df_food['totla amount']>30)]
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  totla amount
# 0         2           19.99         39.98
# 4         3           19.99         59.97

# %%
#est if the start of each string element matches a pattern.
#str.startswith
df_food[df_food['Day'].str.startswith('W')]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 14           1015           E      Green Fuel          Falafel  Wednesday
# 25           1026           G  Chicken Roller   Bucket Special  Wednesday
# 45           1046           K      Green Fuel    Mixed Lentils  Wednesday
# 48           1049           L   BBQ Pit Kings   Smoked Sausage  Wednesday
# 51           1052           L   BBQ Pit Kings             Ribs  Wednesday
# 52           1053           M   Oasis Seafood  Seafood Platter  Wednesday
# 54           1055           M      Green Fuel    Mixed Lentils  Wednesday
#
#     Quantity  Price Per Item  totla amount
# 14         2            4.99          9.98
# 25         1           15.99         15.99
# 45         2            6.99         13.98
# 48         1            7.99          7.99
# 51         3           11.99         35.97
# 52         2           19.99         39.98
# 54         3            6.99         20.97

# %%
df_food[df_food['Day'].str.startswith('S')]
# Out:
#     Food Order ID Customer ID Restaurant Name        Meal Ordered       Day  \
# 11           1012           D  Chicken Roller  Spicy Chicken Wrap  Saturday
# 17           1018           F      Green Fuel          Green Poke  Saturday
# 20           1021           G  Chicken Roller  Spicy Chicken Wrap    Sunday
# 23           1024           G  Chicken Roller             Tenders    Sunday
# 28           1029           H   BBQ Pit Kings                Ribs  Saturday
# 31           1032           H   Oasis Seafood     Seafood Platter  Saturday
# 32           1033           I   Oasis Seafood     Seafood Platter    Sunday
# 36           1037           I  Chicken Roller  Spicy Chicken Wrap    Sunday
# 42           1043           K   BBQ Pit Kings      Smoked Chicken  Saturday
# 43           1044           K  Chicken Roller      Bucket Special  Saturday
# 47           1048           K      Green Fuel             Falafel  Saturday
#
#     Quantity  Price Per Item  totla amount
# 11         1            3.99          3.99
# 17         3            8.99         26.97
# 20         2            3.99          7.98
# 23         3            4.99         14.97
# 28         1           11.99         11.99
# 31         2           19.99         39.98
# 32         2           19.99         39.98
# 36         1            3.99          3.99
# 42         3           12.99         38.97
# 43         2           15.99         31.98
# 47         1            4.99          4.99

# %%
#endswith(pat, na=None)
#Test if the end of each string element matches a pattern.
df_food[df_food['Meal Ordered'].str.endswith("er")]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 0            1001           A   Oasis Seafood  Seafood Platter    Tuesday
# 4            1005           B   Oasis Seafood  Seafood Platter    Tuesday
# 12           1013           E   Oasis Seafood  Seafood Platter     Friday
# 24           1025           G   Oasis Seafood  Seafood Platter     Friday
# 31           1032           H   Oasis Seafood  Seafood Platter   Saturday
# 32           1033           I   Oasis Seafood  Seafood Platter     Sunday
# 49           1050           L   Oasis Seafood  Seafood Platter     Monday
# 52           1053           M   Oasis Seafood  Seafood Platter  Wednesday
#
#     Quantity  Price Per Item  totla amount
# 0          2           19.99         39.98
# 4          3           19.99         59.97
# 12         3           19.99         59.97
# 24         2           19.99         39.98
# 31         2           19.99         39.98
# 32         2           19.99         39.98
# 49         2           19.99         39.98
# 52         2           19.99         39.98

# %%
#str.contains(pat, case=True, flags=0, na=None, regex=True)
#Test if pattern or regex is contained within a string of a Series or Index.
df_food[df_food['Restaurant Name'].str.contains("in")]
# Out:
#     Food Order ID Customer ID Restaurant Name    Meal Ordered        Day  \
# 6            1007           C   BBQ Pit Kings            Ribs     Monday
# 7            1008           C   BBQ Pit Kings  Smoked Chicken    Tuesday
# 8            1009           C   BBQ Pit Kings  Smoked Sausage    Tuesday
# 13           1014           E   BBQ Pit Kings            Ribs    Tuesday
# 16           1017           F   BBQ Pit Kings  Smoked Chicken     Monday
# 22           1023           G   BBQ Pit Kings  Smoked Sausage     Friday
# 28           1029           H   BBQ Pit Kings            Ribs   Saturday
# 29           1030           H   BBQ Pit Kings            Ribs    Tuesday
# 33           1034           I   BBQ Pit Kings  Smoked Chicken   Thursday
# 35           1036           I   BBQ Pit Kings            Ribs    Tuesday
# 37           1038           I   BBQ Pit Kings            Ribs     Monday
# 38           1039           I   BBQ Pit Kings            Ribs    Tuesday
# 42           1043           K   BBQ Pit Kings  Smoked Chicken   Saturday
# 48           1049           L   BBQ Pit Kings  Smoked Sausage  Wednesday
# 51           1052           L   BBQ Pit Kings            Ribs  Wednesday
# 53           1054           M   BBQ Pit Kings  Smoked Chicken   Thursday
#
#     Quantity  Price Per Item  Total Amount
# 6          3           11.99         35.97
# 7          1           12.99         12.99
# 8          1            7.99          7.99
# 13         1           11.99         11.99
# 16         3           12.99         38.97
# 22         1            7.99          7.99
# 28         1           11.99         11.99
# 29         1           11.99         11.99
# 33         3           12.99         38.97
# 35         1           11.99         11.99
# 37         2           11.99         23.98
# 38         1           11.99         11.99
# 42         3           12.99         38.97
# 48         1            7.99          7.99
# 51         3           11.99         35.97
# 53         1           12.99         12.99

# %%
#DataFrame.sort_values
#Sort by the values along either axis
df_food.sort_values(by="Total Amount", ascending=True).head(10)
# Out:
#     Food Order ID Customer ID Restaurant Name        Meal Ordered       Day  \
# 39           1040           J  Chicken Roller  Spicy Chicken Wrap    Monday
# 30           1031           H  Chicken Roller  Spicy Chicken Wrap    Monday
# 36           1037           I  Chicken Roller  Spicy Chicken Wrap    Sunday
# 11           1012           D  Chicken Roller  Spicy Chicken Wrap  Saturday
# 19           1020           F      Green Fuel             Falafel    Friday
# 47           1048           K      Green Fuel             Falafel  Saturday
# 46           1047           K  Chicken Roller             Tenders   Tuesday
# 15           1016           E  Chicken Roller             Tenders    Friday
# 5            1006           C   Oasis Seafood         Cod Fingers    Monday
# 20           1021           G  Chicken Roller  Spicy Chicken Wrap    Sunday
#
#     Quantity  Price Per Item  Total Amount
# 39         1            3.99          3.99
# 30         1            3.99          3.99
# 36         1            3.99          3.99
# 11         1            3.99          3.99
# 19         1            4.99          4.99
# 47         1            4.99          4.99
# 46         1            4.99          4.99
# 15         1            4.99          4.99
# 5          1            5.99          5.99
# 20         2            3.99          7.98

# %%
df_food.sort_values(by="Total Amount", ascending=False).head(10)
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 12           1013           E   Oasis Seafood  Seafood Platter     Friday
# 4            1005           B   Oasis Seafood  Seafood Platter    Tuesday
# 18           1019           F  Chicken Roller   Bucket Special    Tuesday
# 0            1001           A   Oasis Seafood  Seafood Platter    Tuesday
# 52           1053           M   Oasis Seafood  Seafood Platter  Wednesday
# 49           1050           L   Oasis Seafood  Seafood Platter     Monday
# 31           1032           H   Oasis Seafood  Seafood Platter   Saturday
# 32           1033           I   Oasis Seafood  Seafood Platter     Sunday
# 24           1025           G   Oasis Seafood  Seafood Platter     Friday
# 16           1017           F   BBQ Pit Kings   Smoked Chicken     Monday
#
#     Quantity  Price Per Item  Total Amount
# 12         3           19.99         59.97
# 4          3           19.99         59.97
# 18         3           15.99         47.97
# 0          2           19.99         39.98
# 52         2           19.99         39.98
# 49         2           19.99         39.98
# 31         2           19.99         39.98
# 32         2           19.99         39.98
# 24         2           19.99         39.98
# 16         3           12.99         38.97

# %%
df_food.sort_values(by=["Total Amount","Quantity"], ascending=False).head(10)
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 4            1005           B   Oasis Seafood  Seafood Platter    Tuesday
# 12           1013           E   Oasis Seafood  Seafood Platter     Friday
# 18           1019           F  Chicken Roller   Bucket Special    Tuesday
# 0            1001           A   Oasis Seafood  Seafood Platter    Tuesday
# 24           1025           G   Oasis Seafood  Seafood Platter     Friday
# 31           1032           H   Oasis Seafood  Seafood Platter   Saturday
# 32           1033           I   Oasis Seafood  Seafood Platter     Sunday
# 49           1050           L   Oasis Seafood  Seafood Platter     Monday
# 52           1053           M   Oasis Seafood  Seafood Platter  Wednesday
# 16           1017           F   BBQ Pit Kings   Smoked Chicken     Monday
#
#     Quantity  Price Per Item  Total Amount
# 4          3           19.99         59.97
# 12         3           19.99         59.97
# 18         3           15.99         47.97
# 0          2           19.99         39.98
# 24         2           19.99         39.98
# 31         2           19.99         39.98
# 32         2           19.99         39.98
# 49         2           19.99         39.98
# 52         2           19.99         39.98
# 16         3           12.99         38.97

# %%
df_food.sort_values(by=["Meal Ordered","Quantity"], ascending=(False,True)).head(10)
# Out:
#     Food Order ID Customer ID Restaurant Name        Meal Ordered       Day  \
# 15           1016           E  Chicken Roller             Tenders    Friday
# 46           1047           K  Chicken Roller             Tenders   Tuesday
# 10           1011           D  Chicken Roller             Tenders  Thursday
# 23           1024           G  Chicken Roller             Tenders    Sunday
# 11           1012           D  Chicken Roller  Spicy Chicken Wrap  Saturday
# 30           1031           H  Chicken Roller  Spicy Chicken Wrap    Monday
# 36           1037           I  Chicken Roller  Spicy Chicken Wrap    Sunday
# 39           1040           J  Chicken Roller  Spicy Chicken Wrap    Monday
# 20           1021           G  Chicken Roller  Spicy Chicken Wrap    Sunday
# 21           1022           G  Chicken Roller  Spicy Chicken Wrap    Monday
#
#     Quantity  Price Per Item  Total Amount
# 15         1            4.99          4.99
# 46         1            4.99          4.99
# 10         2            4.99          9.98
# 23         3            4.99         14.97
# 11         1            3.99          3.99
# 30         1            3.99          3.99
# 36         1            3.99          3.99
# 39         1            3.99          3.99
# 20         2            3.99          7.98
# 21         2            3.99          7.98

# %%
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount
# 0         2           19.99         39.98
# 1         3            8.99         26.97
# 2         3            4.99         14.97
# 3         3            6.99         20.97
# 4         3           19.99         59.97

# %%
#pandas.DataFrame.loc
#Access a group of rows and columns by label(s) or a boolean array.
df_food.loc[1,['Meal Ordered']]
# Out:
# Meal Ordered    Scallops
# Name: 1, dtype: object

# %%
df_food.loc[1,:]
# Out:
# Food Order ID               1002
# Customer ID                    A
# Restaurant Name    Oasis Seafood
# Meal Ordered            Scallops
# Day                       Friday
# Quantity                       3
# Price Per Item              8.99
# Total Amount               26.97
# Name: 1, dtype: object

# %%
df_food.loc[df_food['Price Per Item']>15,:]
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 0            1001           A   Oasis Seafood  Seafood Platter    Tuesday
# 4            1005           B   Oasis Seafood  Seafood Platter    Tuesday
# 9            1010           C  Chicken Roller   Bucket Special    Tuesday
# 12           1013           E   Oasis Seafood  Seafood Platter     Friday
# 18           1019           F  Chicken Roller   Bucket Special    Tuesday
# 24           1025           G   Oasis Seafood  Seafood Platter     Friday
# 25           1026           G  Chicken Roller   Bucket Special  Wednesday
# 31           1032           H   Oasis Seafood  Seafood Platter   Saturday
# 32           1033           I   Oasis Seafood  Seafood Platter     Sunday
# 43           1044           K  Chicken Roller   Bucket Special   Saturday
# 44           1045           K  Chicken Roller   Bucket Special     Friday
# 49           1050           L   Oasis Seafood  Seafood Platter     Monday
# 52           1053           M   Oasis Seafood  Seafood Platter  Wednesday
#
#     Quantity  Price Per Item  Total Amount
# 0          2           19.99         39.98
# 4          3           19.99         59.97
# 9          2           15.99         31.98
# 12         3           19.99         59.97
# 18         3           15.99         47.97
# 24         2           19.99         39.98
# 25         1           15.99         15.99
# 31         2           19.99         39.98
# 32         2           19.99         39.98
# 43         2           15.99         31.98
# 44         2           15.99         31.98
# 49         2           19.99         39.98
# 52         2           19.99         39.98

# %%
df_food.loc[df_food['Price Per Item']>15,:].sort_values(by=['Meal Ordered','Total Amount'],\
                                                        ascending=(True,True))
# Out:
#     Food Order ID Customer ID Restaurant Name     Meal Ordered        Day  \
# 25           1026           G  Chicken Roller   Bucket Special  Wednesday
# 9            1010           C  Chicken Roller   Bucket Special    Tuesday
# 43           1044           K  Chicken Roller   Bucket Special   Saturday
# 44           1045           K  Chicken Roller   Bucket Special     Friday
# 18           1019           F  Chicken Roller   Bucket Special    Tuesday
# 0            1001           A   Oasis Seafood  Seafood Platter    Tuesday
# 24           1025           G   Oasis Seafood  Seafood Platter     Friday
# 31           1032           H   Oasis Seafood  Seafood Platter   Saturday
# 32           1033           I   Oasis Seafood  Seafood Platter     Sunday
# 49           1050           L   Oasis Seafood  Seafood Platter     Monday
# 52           1053           M   Oasis Seafood  Seafood Platter  Wednesday
# 4            1005           B   Oasis Seafood  Seafood Platter    Tuesday
# 12           1013           E   Oasis Seafood  Seafood Platter     Friday
#
#     Quantity  Price Per Item  Total Amount
# 25         1           15.99         15.99
# 9          2           15.99         31.98
# 43         2           15.99         31.98
# 44         2           15.99         31.98
# 18         3           15.99         47.97
# 0          2           19.99         39.98
# 24         2           19.99         39.98
# 31         2           19.99         39.98
# 32         2           19.99         39.98
# 49         2           19.99         39.98
# 52         2           19.99         39.98
# 4          3           19.99         59.97
# 12         3           19.99         59.97

# %%
#Bucketing or Binning of continuous variable in pandas python to discrete chunks is depicted
#for bucketing using loc method, first you must create column with defualt value
df_food['Amount - Bucket'] = '--out of bound--'
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount   Amount - Bucket
# 0         2           19.99         39.98  --out of bound--
# 1         3            8.99         26.97  --out of bound--
# 2         3            4.99         14.97  --out of bound--
# 3         3            6.99         20.97  --out of bound--
# 4         3           19.99         59.97  --out of bound--

# %%
#then filter values and assign label to them
df_food.loc[(df_food['Total Amount']>0)&(df_food['Total Amount']<=20),'Amount - Bucket']='Low'
df_food.loc[(df_food['Total Amount']>20)&(df_food['Total Amount']<=40),'Amount - Bucket']='Mid'
df_food.loc[(df_food['Total Amount']>40),'Amount - Bucket']='High'

# %%
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount Amount - Bucket
# 0         2           19.99         39.98             Mid
# 1         3            8.99         26.97             Mid
# 2         3            4.99         14.97             Low
# 3         3            6.99         20.97             Mid
# 4         3           19.99         59.97            High

# %%
#for bucketing you can use another way, using cau method
#pandas.cut
#Bin values into discrete intervals.Use cut when you need to segment and sort data values into bins
bin = [0,20,40,60]
df_food['Amount - Binning'] = pd.cut(df_food['Total Amount'],bin)
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount Amount - Bucket Amount - Binning
# 0         2           19.99         39.98             Mid         (20, 40]
# 1         3            8.99         26.97             Mid         (20, 40]
# 2         3            4.99         14.97             Low          (0, 20]
# 3         3            6.99         20.97             Mid         (20, 40]
# 4         3           19.99         59.97            High         (40, 60]

# %%
#We will be assigning label to each bin
bin_label = ['low','mid','high']
df_food['Amount - Bucketing'] = pd.cut(df_food['Total Amount'],bin,labels=bin_label)
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount Amount - Bucket Amount - Binning  \
# 0         2           19.99         39.98             Mid         (20, 40]
# 1         3            8.99         26.97             Mid         (20, 40]
# 2         3            4.99         14.97             Low          (0, 20]
# 3         3            6.99         20.97             Mid         (20, 40]
# 4         3           19.99         59.97            High         (40, 60]
#
#   Amount - Bucketing
# 0                mid
# 1                mid
# 2                low
# 3                mid
# 4               high

# %%
#bucketing using loc method
df_food['Vegan'] = 'Not Vegan'
df_food.loc[df_food['Restaurant Name'].str.contains('Green'),'Vegan']='Vegan'
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount Amount - Bucket Amount - Binning  \
# 0         2           19.99         39.98             Mid         (20, 40]
# 1         3            8.99         26.97             Mid         (20, 40]
# 2         3            4.99         14.97             Low          (0, 20]
# 3         3            6.99         20.97             Mid         (20, 40]
# 4         3           19.99         59.97            High         (40, 60]
#
#   Amount - Bucketing      Vegan
# 0                mid  Not Vegan
# 1                mid  Not Vegan
# 2                low      Vegan
# 3                mid      Vegan
# 4               high  Not Vegan

# %%
#replacing data
df_food.head()
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001           A   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002           A   Oasis Seafood         Scallops   Friday
# 2           1003           A      Green Fuel          Falafel   Friday
# 3           1004           B      Green Fuel    Mixed Lentils   Friday
# 4           1005           B   Oasis Seafood  Seafood Platter  Tuesday
#
#    Quantity  Price Per Item  Total Amount
# 0         2           19.99         39.98
# 1         3            8.99         26.97
# 2         3            4.99         14.97
# 3         3            6.99         20.97
# 4         3           19.99         59.97

# %%
df_food['Customer ID'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M'],
#       dtype=object)

# %%
#DataFrame.replace
#Values of the DataFrame are replaced with other values dynamically.
df_food['Customer ID'].replace({'A':'A001','B':'B001','C':'C001','D':'D001','E':'E001'\
                               ,'F':'F001','G':'G001','H':'H001','I':'I001','J':'J001'\
                               ,'K':'K001','L':'L001','M':'M001'},inplace=True)

# %%
df_food.head(10)
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered      Day  \
# 0           1001        A001   Oasis Seafood  Seafood Platter  Tuesday
# 1           1002        A001   Oasis Seafood         Scallops   Friday
# 2           1003        A001      Green Fuel          Falafel   Friday
# 3           1004        B001      Green Fuel    Mixed Lentils   Friday
# 4           1005        B001   Oasis Seafood  Seafood Platter  Tuesday
# 5           1006        C001   Oasis Seafood      Cod Fingers   Monday
# 6           1007        C001   BBQ Pit Kings             Ribs   Monday
# 7           1008        C001   BBQ Pit Kings   Smoked Chicken  Tuesday
# 8           1009        C001   BBQ Pit Kings   Smoked Sausage  Tuesday
# 9           1010        C001  Chicken Roller   Bucket Special  Tuesday
#
#    Quantity  Price Per Item  Total Amount
# 0         2           19.99         39.98
# 1         3            8.99         26.97
# 2         3            4.99         14.97
# 3         3            6.99         20.97
# 4         3           19.99         59.97
# 5         1            5.99          5.99
# 6         3           11.99         35.97
# 7         1           12.99         12.99
# 8         1            7.99          7.99
# 9         2           15.99         31.98

# %%
df_food['Day'].unique()
# Out:
# array(['Tuesday', 'Friday', 'Monday', 'Thursday', 'Saturday', 'Wednesday',
#        'Sunday'], dtype=object)

# %%
df_food['Day'].replace({'Monday':'01 - Monday','Tuesday':'02 - Tuesday'\
                       ,'Wednesday':'03 - Wednesday','Thursday':'04 - Thursday'\
                       ,'Friday':'05 - Friday','Saturday':'06 - Saturday'\
                       ,'Sunday':'07 - Sunday'},inplace = True)

# %%
df_food.head(10)
# Out:
#    Food Order ID Customer ID Restaurant Name     Meal Ordered           Day  \
# 0           1001        A001   Oasis Seafood  Seafood Platter  02 - Tuesday
# 1           1002        A001   Oasis Seafood         Scallops   05 - Friday
# 2           1003        A001      Green Fuel          Falafel   05 - Friday
# 3           1004        B001      Green Fuel    Mixed Lentils   05 - Friday
# 4           1005        B001   Oasis Seafood  Seafood Platter  02 - Tuesday
# 5           1006        C001   Oasis Seafood      Cod Fingers   01 - Monday
# 6           1007        C001   BBQ Pit Kings             Ribs   01 - Monday
# 7           1008        C001   BBQ Pit Kings   Smoked Chicken  02 - Tuesday
# 8           1009        C001   BBQ Pit Kings   Smoked Sausage  02 - Tuesday
# 9           1010        C001  Chicken Roller   Bucket Special  02 - Tuesday
#
#    Quantity  Price Per Item  Total Amount
# 0         2           19.99         39.98
# 1         3            8.99         26.97
# 2         3            4.99         14.97
# 3         3            6.99         20.97
# 4         3           19.99         59.97
# 5         1            5.99          5.99
# 6         3           11.99         35.97
# 7         1           12.99         12.99
# 8         1            7.99          7.99
# 9         2           15.99         31.98

# %%
df_food.sort_values(by=['Day'],ascending = True)
# Out:
#     Food Order ID Customer ID Restaurant Name        Meal Ordered  \
# 27           1028        H001   Oasis Seafood         Cod Fingers
# 50           1051        L001   Oasis Seafood         Cod Fingers
# 49           1050        L001   Oasis Seafood     Seafood Platter
# 21           1022        G001  Chicken Roller  Spicy Chicken Wrap
# 40           1041        J001      Green Fuel             Falafel
# 5            1006        C001   Oasis Seafood         Cod Fingers
# 6            1007        C001   BBQ Pit Kings                Ribs
# 39           1040        J001  Chicken Roller  Spicy Chicken Wrap
# 16           1017        F001   BBQ Pit Kings      Smoked Chicken
# 37           1038        I001   BBQ Pit Kings                Ribs
# 26           1027        H001      Green Fuel             Falafel
# 34           1035        I001   Oasis Seafood            Scallops
# 30           1031        H001  Chicken Roller  Spicy Chicken Wrap
# 38           1039        I001   BBQ Pit Kings                Ribs
# 35           1036        I001   BBQ Pit Kings                Ribs
# 46           1047        K001  Chicken Roller             Tenders
# 29           1030        H001   BBQ Pit Kings                Ribs
# 18           1019        F001  Chicken Roller      Bucket Special
# 0            1001        A001   Oasis Seafood     Seafood Platter
# 8            1009        C001   BBQ Pit Kings      Smoked Sausage
# 7            1008        C001   BBQ Pit Kings      Smoked Chicken
# 4            1005        B001   Oasis Seafood     Seafood Platter
# 13           1014        E001   BBQ Pit Kings                Ribs
# 9            1010        C001  Chicken Roller      Bucket Special
# 45           1046        K001      Green Fuel       Mixed Lentils
# 14           1015        E001      Green Fuel             Falafel
# 54           1055        M001      Green Fuel       Mixed Lentils
# 48           1049        L001   BBQ Pit Kings      Smoked Sausage
# 51           1052        L001   BBQ Pit Kings                Ribs
# 52           1053        M001   Oasis Seafood     Seafood Platter
# 25           1026        G001  Chicken Roller      Bucket Special
# 53           1054        M001   BBQ Pit Kings      Smoked Chicken
# 33           1034        I001   BBQ Pit Kings      Smoked Chicken
# 10           1011        D001  Chicken Roller             Tenders
# 2            1003        A001      Green Fuel             Falafel
# 1            1002        A001   Oasis Seafood            Scallops
# 44           1045        K001  Chicken Roller      Bucket Special
# 41           1042        J001   Oasis Seafood            Scallops
# 3            1004        B001      Green Fuel       Mixed Lentils
# 19           1020        F001      Green Fuel             Falafel
# 12           1013        E001   Oasis Seafood     Seafood Platter
# 24           1025        G001   Oasis Seafood     Seafood Platter
# 22           1023        G001   BBQ Pit Kings      Smoked Sausage
# 15           1016        E001  Chicken Roller             Tenders
# 11           1012        D001  Chicken Roller  Spicy Chicken Wrap
# 42           1043        K001   BBQ Pit Kings      Smoked Chicken
# 43           1044        K001  Chicken Roller      Bucket Special
# 31           1032        H001   Oasis Seafood     Seafood Platter
# 28           1029        H001   BBQ Pit Kings                Ribs
# 47           1048        K001      Green Fuel             Falafel
# 17           1018        F001      Green Fuel          Green Poke
# 32           1033        I001   Oasis Seafood     Seafood Platter
# 23           1024        G001  Chicken Roller             Tenders
# 20           1021        G001  Chicken Roller  Spicy Chicken Wrap
# 36           1037        I001  Chicken Roller  Spicy Chicken Wrap
#
#                Day  Quantity  Price Per Item  Total Amount
# 27     01 - Monday         3            5.99         17.97
# 50     01 - Monday         3            5.99         17.97
# 49     01 - Monday         2           19.99         39.98
# 21     01 - Monday         2            3.99          7.98
# 40     01 - Monday         2            4.99          9.98
# 5      01 - Monday         1            5.99          5.99
# 6      01 - Monday         3           11.99         35.97
# 39     01 - Monday         1            3.99          3.99
# 16     01 - Monday         3           12.99         38.97
# 37     01 - Monday         2           11.99         23.98
# 26     01 - Monday         2            4.99          9.98
# 34     01 - Monday         1            8.99          8.99
# 30     01 - Monday         1            3.99          3.99
# 38    02 - Tuesday         1           11.99         11.99
# 35    02 - Tuesday         1           11.99         11.99
# 46    02 - Tuesday         1            4.99          4.99
# 29    02 - Tuesday         1           11.99         11.99
# 18    02 - Tuesday         3           15.99         47.97
# 0     02 - Tuesday         2           19.99         39.98
# 8     02 - Tuesday         1            7.99          7.99
# 7     02 - Tuesday         1           12.99         12.99
# 4     02 - Tuesday         3           19.99         59.97
# 13    02 - Tuesday         1           11.99         11.99
# 9     02 - Tuesday         2           15.99         31.98
# 45  03 - Wednesday         2            6.99         13.98
# 14  03 - Wednesday         2            4.99          9.98
# 54  03 - Wednesday         3            6.99         20.97
# 48  03 - Wednesday         1            7.99          7.99
# 51  03 - Wednesday         3           11.99         35.97
# 52  03 - Wednesday         2           19.99         39.98
# 25  03 - Wednesday         1           15.99         15.99
# 53   04 - Thursday         1           12.99         12.99
# 33   04 - Thursday         3           12.99         38.97
# 10   04 - Thursday         2            4.99          9.98
# 2      05 - Friday         3            4.99         14.97
# 1      05 - Friday         3            8.99         26.97
# 44     05 - Friday         2           15.99         31.98
# 41     05 - Friday         1            8.99          8.99
# 3      05 - Friday         3            6.99         20.97
# 19     05 - Friday         1            4.99          4.99
# 12     05 - Friday         3           19.99         59.97
# 24     05 - Friday         2           19.99         39.98
# 22     05 - Friday         1            7.99          7.99
# 15     05 - Friday         1            4.99          4.99
# 11   06 - Saturday         1            3.99          3.99
# 42   06 - Saturday         3           12.99         38.97
# 43   06 - Saturday         2           15.99         31.98
# 31   06 - Saturday         2           19.99         39.98
# 28   06 - Saturday         1           11.99         11.99
# 47   06 - Saturday         1            4.99          4.99
# 17   06 - Saturday         3            8.99         26.97
# 32     07 - Sunday         2           19.99         39.98
# 23     07 - Sunday         3            4.99         14.97
# 20     07 - Sunday         2            3.99          7.98
# 36     07 - Sunday         1            3.99          3.99

# %%
#Group DataFrame using a mapper or by a Series of columns
df_food.groupby('Customer ID')

# %%
df_food.groupby('Customer ID').max()
# Out:
#              Food Order ID Restaurant Name        Meal Ordered  \
# Customer ID
# A001                  1003   Oasis Seafood     Seafood Platter
# B001                  1005   Oasis Seafood     Seafood Platter
# C001                  1010   Oasis Seafood      Smoked Sausage
# D001                  1012  Chicken Roller             Tenders
# E001                  1016   Oasis Seafood             Tenders
# F001                  1020      Green Fuel      Smoked Chicken
# G001                  1026   Oasis Seafood             Tenders
# H001                  1032   Oasis Seafood  Spicy Chicken Wrap
# I001                  1039   Oasis Seafood  Spicy Chicken Wrap
# J001                  1042   Oasis Seafood  Spicy Chicken Wrap
# K001                  1048      Green Fuel             Tenders
# L001                  1052   Oasis Seafood      Smoked Sausage
# M001                  1055   Oasis Seafood      Smoked Chicken
#
#                         Day  Quantity  Price Per Item  Total Amount
# Customer ID
# A001            05 - Friday         3           19.99         39.98
# B001            05 - Friday         3           19.99         59.97
# C001           02 - Tuesday         3           15.99         35.97
# D001          06 - Saturday         2            4.99          9.98
# E001            05 - Friday         3           19.99         59.97
# F001          06 - Saturday         3           15.99         47.97
# G001            07 - Sunday         3           19.99         39.98
# H001          06 - Saturday         3           19.99         39.98
# I001            07 - Sunday         3           19.99         39.98
# J001            05 - Friday         2            8.99          9.98
# K001          06 - Saturday         3           15.99         38.97
# L001         03 - Wednesday         3           19.99         39.98
# M001          04 - Thursday         3           19.99         39.98

# %%
df_food.groupby(['Customer ID'],as_index = False).mean()
# Out:
#    Customer ID  Food Order ID  Quantity  Price Per Item  Total Amount
# 0         A001         1002.0  2.666667       11.323333     27.306667
# 1         B001         1004.5  3.000000       13.490000     40.470000
# 2         C001         1008.0  1.600000       10.990000     18.984000
# 3         D001         1011.5  1.500000        4.490000      6.985000
# 4         E001         1014.5  1.750000       10.490000     21.732500
# 5         F001         1018.5  2.500000       10.740000     29.725000
# 6         G001         1023.5  1.833333        9.490000     15.815000
# 7         H001         1029.5  1.666667        9.823333     15.983333
# 8         I001         1036.0  1.571429       11.704286     19.984286
# 9         J001         1041.0  1.333333        5.990000      7.653333
# 10        K001         1045.5  1.833333       10.323333     21.148333
# 11        L001         1050.5  2.250000       11.490000     25.477500
# 12        M001         1054.0  2.000000       13.323333     24.646667

# %%
df_food.groupby(['Customer ID'],as_index =False).count()
# Out:
#    Customer ID  Food Order ID  Restaurant Name  Meal Ordered  Day  Quantity  \
# 0         A001              3                3             3    3         3
# 1         B001              2                2             2    2         2
# 2         C001              5                5             5    5         5
# 3         D001              2                2             2    2         2
# 4         E001              4                4             4    4         4
# 5         F001              4                4             4    4         4
# 6         G001              6                6             6    6         6
# 7         H001              6                6             6    6         6
# 8         I001              7                7             7    7         7
# 9         J001              3                3             3    3         3
# 10        K001              6                6             6    6         6
# 11        L001              4                4             4    4         4
# 12        M001              3                3             3    3         3
#
#     Price Per Item  Total Amount
# 0                3             3
# 1                2             2
# 2                5             5
# 3                2             2
# 4                4             4
# 5                4             4
# 6                6             6
# 7                6             6
# 8                7             7
# 9                3             3
# 10               6             6
# 11               4             4
# 12               3             3

# %%
df_food.groupby(['Customer ID'],as_index = False).agg({'Total Amount':['max','min','mean','count']})
# Out:
#    Customer ID Total Amount
#                         max    min       mean count
# 0         A001        39.98  14.97  27.306667     3
# 1         B001        59.97  20.97  40.470000     2
# 2         C001        35.97   5.99  18.984000     5
# 3         D001         9.98   3.99   6.985000     2
# 4         E001        59.97   4.99  21.732500     4
# 5         F001        47.97   4.99  29.725000     4
# 6         G001        39.98   7.98  15.815000     6
# 7         H001        39.98   3.99  15.983333     6
# 8         I001        39.98   3.99  19.984286     7
# 9         J001         9.98   3.99   7.653333     3
# 10        K001        38.97   4.99  21.148333     6
# 11        L001        39.98   7.99  25.477500     4
# 12        M001        39.98  12.99  24.646667     3

# %%
df_food.groupby(['Restaurant Name'],as_index = False).agg({'Total Amount':['max','min','mean','count']})
# Out:
#   Restaurant Name Total Amount
#                            max   min       mean count
# 0   BBQ Pit Kings        38.97  7.99  20.170625    16
# 1  Chicken Roller        47.97  3.99  15.116667    15
# 2      Green Fuel        26.97  4.99  13.778000    10
# 3   Oasis Seafood        59.97  5.99  31.907143    14

# %%
df_food.groupby(['Day'],as_index = False).agg({'Total Amount':['max','min','mean','count']})
# Out:
#               Day Total Amount
#                            max   min       mean count
# 0     01 - Monday        39.98  3.99  17.364615    13
# 1    02 - Tuesday        59.97  4.99  23.075455    11
# 2  03 - Wednesday        39.98  7.99  20.694286     7
# 3   04 - Thursday        38.97  9.98  20.646667     3
# 4     05 - Friday        59.97  4.99  22.180000    10
# 5   06 - Saturday        39.98  3.99  22.695714     7
# 6     07 - Sunday        39.98  3.99  16.730000     4

# %%
df_food.groupby(['Restaurant Name','Day']).mean()
# Out:
#                                 Food Order ID  Quantity  Price Per Item  \
# Restaurant Name Day
# BBQ Pit Kings   01 - Monday       1020.666667  2.666667       12.323333
#                 02 - Tuesday      1022.666667  1.000000       11.490000
#                 03 - Wednesday    1050.500000  2.000000        9.990000
#                 04 - Thursday     1044.000000  2.000000       12.990000
#                 05 - Friday       1023.000000  1.000000        7.990000
#                 06 - Saturday     1036.000000  2.000000       12.490000
# Chicken Roller  01 - Monday       1031.000000  1.333333        3.990000
#                 02 - Tuesday      1025.333333  2.000000       12.323333
#                 03 - Wednesday    1026.000000  1.000000       15.990000
#                 04 - Thursday     1011.000000  2.000000        4.990000
#                 05 - Friday       1030.500000  1.500000       10.490000
#                 06 - Saturday     1028.000000  1.500000        9.990000
#                 07 - Sunday       1027.333333  2.000000        4.323333
# Green Fuel      01 - Monday       1034.000000  2.000000        4.990000
#                 03 - Wednesday    1038.666667  2.333333        6.323333
#                 05 - Friday       1009.000000  2.333333        5.656667
#                 06 - Saturday     1033.000000  2.000000        6.990000
# Oasis Seafood   01 - Monday       1034.000000  2.000000        9.390000
#                 02 - Tuesday      1003.000000  2.500000       19.990000
#                 03 - Wednesday    1053.000000  2.000000       19.990000
#                 05 - Friday       1020.500000  2.250000       14.490000
#                 06 - Saturday     1032.000000  2.000000       19.990000
#                 07 - Sunday       1033.000000  2.000000       19.990000
#
#                                 Total Amount
# Restaurant Name Day
# BBQ Pit Kings   01 - Monday        32.973333
#                 02 - Tuesday       11.490000
#                 03 - Wednesday     21.980000
#                 04 - Thursday      25.980000
#                 05 - Friday         7.990000
#                 06 - Saturday      25.480000
# Chicken Roller  01 - Monday         5.320000
#                 02 - Tuesday       28.313333
#                 03 - Wednesday     15.990000
#                 04 - Thursday       9.980000
#                 05 - Friday        18.485000
#                 06 - Saturday      17.985000
#                 07 - Sunday         8.980000
# Green Fuel      01 - Monday         9.980000
#                 03 - Wednesday     14.976667
#                 05 - Friday        13.643333
#                 06 - Saturday      15.980000
# Oasis Seafood   01 - Monday        18.180000
#                 02 - Tuesday       49.975000
#                 03 - Wednesday     39.980000
#                 05 - Friday        33.977500
#                 06 - Saturday      39.980000
#                 07 - Sunday        39.980000

# %%
df_food.groupby(['Restaurant Name','Meal Ordered']).sum()
# Out:
#                                     Food Order ID  Quantity  Price Per Item  \
# Restaurant Name Meal Ordered
# BBQ Pit Kings   Ribs                         8245        13           95.92
#                 Smoked Chicken               5156        11           64.95
#                 Smoked Sausage               3081         3           23.97
# Chicken Roller  Bucket Special               5144        10           79.95
#                 Spicy Chicken Wrap           6163         8           23.94
#                 Tenders                      4098         7           19.96
# Green Fuel      Falafel                      6154        11           29.94
#                 Green Poke                   1018         3            8.99
#                 Mixed Lentils                3105         8           20.97
# Oasis Seafood   Cod Fingers                  3085         7           17.97
#                 Scallops                     3079         5           26.97
#                 Seafood Platter              8212        18          159.92
#
#                                     Total Amount
# Restaurant Name Meal Ordered
# BBQ Pit Kings   Ribs                      155.87
#                 Smoked Chicken            142.89
#                 Smoked Sausage             23.97
# Chicken Roller  Bucket Special            159.90
#                 Spicy Chicken Wrap         31.92
#                 Tenders                    34.93
# Green Fuel      Falafel                    54.89
#                 Green Poke                 26.97
#                 Mixed Lentils              55.92
# Oasis Seafood   Cod Fingers                41.93
#                 Scallops                   44.95
#                 Seafood Platter           359.82

# %%
import pandas as pd

# %%
df_football = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\7. Data Analytics (Pandas)\38.1 Football (Soccer) Teams - Null Values.csv')

# %%
df_football.head()
# Out:
#      Team Name  Champions League  League Champions
# 0    Barcelona               5.0              26.0
# 1  Real Madrid              13.0              33.0
# 2    Liverpool               6.0              18.0
# 3      Man Utd               3.0               NaN
# 4     Man City               0.0               6.0

# %%
df_football.describe()
# Out:
#        Champions League  League Champions
# count         11.000000         11.000000
# mean           4.000000         19.000000
# std            3.872983         10.392305
# min            0.000000          6.000000
# 25%            1.000000         10.500000
# 50%            3.000000         18.000000
# 75%            5.500000         27.000000
# max           13.000000         35.000000

# %%
df_football.isna()
# Out:
#     Team Name  Champions League  League Champions
# 0       False             False             False
# 1       False             False             False
# 2       False             False             False
# 3       False             False              True
# 4       False             False             False
# 5       False              True             False
# 6       False             False             False
# 7       False             False             False
# 8       False             False             False
# 9       False             False             False
# 10      False             False             False
# 11      False             False             False

# %%
#The fillna() method allows us to replace empty cells with a value
df_football['Champions League'].fillna(df_football['Champions League'].mean(),inplace=True)

# %%
df_football['League Champions'].fillna(df_football['League Champions'].mean(),inplace=True)

# %%
df_football
# Out:
#         Team Name  Champions League  League Champions
# 0       Barcelona               5.0              26.0
# 1     Real Madrid              13.0              33.0
# 2       Liverpool               6.0              18.0
# 3         Man Utd               3.0              19.0
# 4        Man City               0.0               6.0
# 5         Chelsea               4.0               6.0
# 6             PSG               0.0               8.0
# 7   Bayern Munich               5.0              28.0
# 8         Arsenal               0.0              13.0
# 9        AC Milan               7.0              18.0
# 10    Inter Milan               3.0              18.0
# 11       Juventus               2.0              35.0

# %%
new_df_football = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\7. Data Analytics (Pandas)\38.1 Football (Soccer) Teams - Null Values.csv')
new_df_football['Champions League'].fillna(1,inplace=True)
new_df_football['League Champions'].fillna(20,inplace=True)

# %%
new_df_football = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\7. Data Analytics (Pandas)\38.1 Football (Soccer) Teams - Null Values.csv')

# %%
new_df_football
# Out:
#         Team Name  Champions League  League Champions
# 0       Barcelona               5.0              26.0
# 1     Real Madrid              13.0              33.0
# 2       Liverpool               6.0              18.0
# 3         Man Utd               3.0               NaN
# 4        Man City               0.0               6.0
# 5         Chelsea               NaN               6.0
# 6             PSG               0.0               8.0
# 7   Bayern Munich               5.0              28.0
# 8         Arsenal               0.0              13.0
# 9        AC Milan               7.0              18.0
# 10    Inter Milan               3.0              18.0
# 11       Juventus               2.0              35.0

# %%
new_df_football['Champions League'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# Name: Champions League, dtype: bool

# %%
any(new_df_football['Champions League'].isna())
# Out:
# True

# %%
#if you want to know is NaN in the column, use any method like abouv
for x in new_df_football.columns:
    if any(new_df_football[x].isna()):
        print(x)
# Out:
# Champions League
# League Champions

# %%
def check_NaN(df):
    for col in df.columns:
        if any(df[col].isna()):
            df[col].fillna(df[col].mean(),inplace=True)
    return df

# %%
new_df_football
# Out:
#         Team Name  Champions League  League Champions
# 0       Barcelona               5.0              26.0
# 1     Real Madrid              13.0              33.0
# 2       Liverpool               6.0              18.0
# 3         Man Utd               3.0               NaN
# 4        Man City               0.0               6.0
# 5         Chelsea               NaN               6.0
# 6             PSG               0.0               8.0
# 7   Bayern Munich               5.0              28.0
# 8         Arsenal               0.0              13.0
# 9        AC Milan               7.0              18.0
# 10    Inter Milan               3.0              18.0
# 11       Juventus               2.0              35.0

# %%
new_df_football_withoutNaN=check_NaN(new_df_football)

# %%
new_df_football_withoutNaN
# Out:
#         Team Name  Champions League  League Champions
# 0       Barcelona               5.0              26.0
# 1     Real Madrid              13.0              33.0
# 2       Liverpool               6.0              18.0
# 3         Man Utd               3.0              19.0
# 4        Man City               0.0               6.0
# 5         Chelsea               4.0               6.0
# 6             PSG               0.0               8.0
# 7   Bayern Munich               5.0              28.0
# 8         Arsenal               0.0              13.0
# 9        AC Milan               7.0              18.0
# 10    Inter Milan               3.0              18.0
# 11       Juventus               2.0              35.0

# %%
df_resturant = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\7. Data Analytics (Pandas)\40.1 Restaurants - Duplicates.csv')
df_resturant.head(10)
# Out:
#    Restaurant Name Meal Release Date  Meal      Meal Description  \
# 0       Data Pizza        18/04/2007     1            Meat Feast
# 1       Data Pizza        29/05/2011     2        Chicken Deluxe
# 2       Data Pizza        02/09/2008     3  Chicken and Mushroom
# 3       Data Pizza        04/02/2002     4          Volcano Meat
# 4       Data Pizza        17/04/2006     5      Vegetable Deluxe
# 5       Data Pizza        07/02/2002     6       Spicy Vegetable
# 6       Data Pizza        07/02/2002     6       Spicy Vegetable
# 7       Data Pizza        07/02/2002     6       Spicy Vegetable
# 8  Big Data Burger        27/08/2001     1          Cheeseburger
# 9  Big Data Burger        06/04/2005     2             Hamburger
#
#                Meal Sides   Cost  Quantity
# 0  Garlic Bread and Drink  11.17      9327
# 1  Garlic Bread and Drink   8.59      4836
# 2  Garlic Bread and Drink   9.09      3845
# 3  Garlic Bread and Drink   8.02      7110
# 4  Garlic Bread and Drink   7.46      2339
# 5  Garlic Bread and Drink  11.23      6536
# 6  Garlic Bread and Drink  11.23      6536
# 7  Garlic Bread and Drink  11.23      6536
# 8         Chips and Drink   8.03      6139
# 9         Chips and Drink   5.64      8733

# %%
#Return boolean Series denoting duplicate rows.
df_resturant.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# dtype: bool

# %%
if any(df_resturant.duplicated()):
    print("we have duplicate")
# Out:
# we have duplicate

# %%
#if you want to show duplicated rows
df_resturant[df_resturant.duplicated()]
# Out:
#    Restaurant Name Meal Release Date  Meal Meal Description  \
# 6       Data Pizza        07/02/2002     6  Spicy Vegetable
# 7       Data Pizza        07/02/2002     6  Spicy Vegetable
# 16     Total Tacos        05/11/2004     1      Chilli Taco
# 18     Total Tacos        17/07/2006     2     Chicken Taco
#
#                 Meal Sides   Cost  Quantity
# 6   Garlic Bread and Drink  11.23      6536
# 7   Garlic Bread and Drink  11.23      6536
# 16                   Drink   7.82      7963
# 18                   Drink   9.39      2268

# %%
df_resturant[df_resturant.duplicated(['Quantity'])]
# Out:
#    Restaurant Name Meal Release Date  Meal Meal Description  \
# 6       Data Pizza        07/02/2002     6  Spicy Vegetable
# 7       Data Pizza        07/02/2002     6  Spicy Vegetable
# 16     Total Tacos        05/11/2004     1      Chilli Taco
# 18     Total Tacos        17/07/2006     2     Chicken Taco
#
#                 Meal Sides   Cost  Quantity
# 6   Garlic Bread and Drink  11.23      6536
# 7   Garlic Bread and Drink  11.23      6536
# 16                   Drink   7.82      7963
# 18                   Drink   9.39      2268

# %%
df_resturant[df_resturant.duplicated(['Meal Description'])]
# Out:
#    Restaurant Name Meal Release Date  Meal Meal Description  \
# 6       Data Pizza        07/02/2002     6  Spicy Vegetable
# 7       Data Pizza        07/02/2002     6  Spicy Vegetable
# 16     Total Tacos        05/11/2004     1      Chilli Taco
# 18     Total Tacos        17/07/2006     2     Chicken Taco
#
#                 Meal Sides   Cost  Quantity
# 6   Garlic Bread and Drink  11.23      6536
# 7   Garlic Bread and Drink  11.23      6536
# 16                   Drink   7.82      7963
# 18                   Drink   9.39      2268

# %%
#DataFrame.drop_duplicates
#Return DataFrame with duplicate rows removed.
df_resturant_i = df_resturant.drop_duplicates(df_resturant.columns)

# %%
any(df_resturant_i.duplicated())
# Out:
# False

# %%
def check_duplicate(df):
    if any(df.duplicated()):
        return df.drop_duplicates(df.columns)

# %%
df_resturant_j = check_duplicate(df_resturant)
any(df_resturant_j.duplicated())
# Out:
# False

# %%
import pandas as pd

# %%
df_show_A = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\7. Data Analytics (Pandas)\62.2 Joining - 2 Keys - A.csv')
df_show_B = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\7. Data Analytics (Pandas)\62.1 Joining - 2 Keys - B.csv')

# %%
df_show_A.head()
# Out:
#    Shop ID Department           Shop Name Shop Region  Revenue  Profit
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626

# %%
df_show_B.head()
# Out:
#    Shop ID Department           Shop Name  No of Employees  \
# 0     1001          A  Alpha Technologies              113
# 1     1001          B  Alpha Technologies              101
# 2     1002          A           Beta Shop               72
# 3     1002          B           Beta Shop              115
# 4     1003          A          Gamma Mart              152
#
#    Shop Size (Square Ft)
# 0                   1336
# 1                   1137
# 2                   1120
# 3                   2124
# 4                   1843

# %%
df_show_A.merge(df_show_B,how='inner',left_on='Shop ID',right_on='Shop ID')
# Out:
#     Shop ID Department_x         Shop Name_x Shop Region  Revenue  Profit  \
# 0      1001            A  Alpha Technologies       North   288182  129681
# 1      1001            A  Alpha Technologies       North   288182  129681
# 2      1001            B  Alpha Technologies       North   154447   92668
# 3      1001            B  Alpha Technologies       North   154447   92668
# 4      1002            A           Beta Shop        East   514656  272767
# 5      1002            A           Beta Shop        East   514656  272767
# 6      1002            B           Beta Shop        East   928507  399258
# 7      1002            B           Beta Shop        East   928507  399258
# 8      1003            A          Gamma Mart       South   203069  107626
# 9      1003            A          Gamma Mart       South   203069  107626
# 10     1003            B          Gamma Mart       South   242931  145758
# 11     1003            B          Gamma Mart       South   242931  145758
# 12     1004            A       Delta and Co.        West   821461  361442
# 13     1004            A       Delta and Co.        West   821461  361442
# 14     1004            B       Delta and Co.        West   337696  192486
# 15     1004            B       Delta and Co.        West   337696  192486
#
#    Department_y         Shop Name_y  No of Employees  Shop Size (Square Ft)
# 0             A  Alpha Technologies              113                   1336
# 1             B  Alpha Technologies              101                   1137
# 2             A  Alpha Technologies              113                   1336
# 3             B  Alpha Technologies              101                   1137
# 4             A           Beta Shop               72                   1120
# 5             B           Beta Shop              115                   2124
# 6             A           Beta Shop               72                   1120
# 7             B           Beta Shop              115                   2124
# 8             A          Gamma Mart              152                   1843
# 9             B          Gamma Mart              124                   1269
# 10            A          Gamma Mart              152                   1843
# 11            B          Gamma Mart              124                   1269
# 12            A       Delta and Co.              155                   2448
# 13            B       Delta and Co.              121                   2323
# 14            A       Delta and Co.              155                   2448
# 15            B       Delta and Co.              121                   2323

# %%
pd.merge(df_show_A,df_show_B,how='left',left_on=['Shop ID','Department'],right_on=['Shop ID','Department'])
# Out:
#    Shop ID Department         Shop Name_x Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#           Shop Name_y  No of Employees  Shop Size (Square Ft)
# 0  Alpha Technologies              113                   1336
# 1  Alpha Technologies              101                   1137
# 2           Beta Shop               72                   1120
# 3           Beta Shop              115                   2124
# 4          Gamma Mart              152                   1843
# 5          Gamma Mart              124                   1269
# 6       Delta and Co.              155                   2448
# 7       Delta and Co.              121                   2323

# %%
#if you want to join two dataframe with more than one culomns, use merge
df_merge_AB = pd.merge(df_show_A,df_show_B,how='left',left_on=['Shop ID','Department'],right_on=['Shop ID','Department'])

# %%
df_merge_AB
# Out:
#    Shop ID Department         Shop Name_x Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#           Shop Name_y  No of Employees  Shop Size (Square Ft)
# 0  Alpha Technologies              113                   1336
# 1  Alpha Technologies              101                   1137
# 2           Beta Shop               72                   1120
# 3           Beta Shop              115                   2124
# 4          Gamma Mart              152                   1843
# 5          Gamma Mart              124                   1269
# 6       Delta and Co.              155                   2448
# 7       Delta and Co.              121                   2323

# %%
df_merge_AB['Expensive'] = df_merge_AB['Revenue'] - df_merge_AB['Profit']

# %%
df_merge_AB
# Out:
#    Shop ID Department         Shop Name_x Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#           Shop Name_y  No of Employees  Shop Size (Square Ft)  Expensive
# 0  Alpha Technologies              113                   1336     158501
# 1  Alpha Technologies              101                   1137      61779
# 2           Beta Shop               72                   1120     241889
# 3           Beta Shop              115                   2124     529249
# 4          Gamma Mart              152                   1843      95443
# 5          Gamma Mart              124                   1269      97173
# 6       Delta and Co.              155                   2448     460019
# 7       Delta and Co.              121                   2323     145210

# %%
#for cleaning data from unwanted columns, use this format
df_AB_clean = df_merge_AB[['Shop ID','Department','Shop Name_x','Shop Region','Revenue','Profit'\
                          ,'Expensive','No of Employees','Shop Size (Square Ft)']]

# %%
df_AB_clean
# Out:
#    Shop ID Department         Shop Name_x Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#    Expensive  No of Employees  Shop Size (Square Ft)
# 0     158501              113                   1336
# 1      61779              101                   1137
# 2     241889               72                   1120
# 3     529249              115                   2124
# 4      95443              152                   1843
# 5      97173              124                   1269
# 6     460019              155                   2448
# 7     145210              121                   2323

# %%
#for rename data frame, use dictionary like this
df_AB_master = df_AB_clean.rename(columns={'Shop Name_x':'Shop Name'})

# %%
df_AB_master
# Out:
#    Shop ID Department           Shop Name Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#    Expensive  No of Employees  Shop Size (Square Ft)
# 0     158501              113                   1336
# 1      61779              101                   1137
# 2     241889               72                   1120
# 3     529249              115                   2124
# 4      95443              152                   1843
# 5      97173              124                   1269
# 6     460019              155                   2448
# 7     145210              121                   2323

# %%
#if you want to calculate comulative sum or runing total, use this method
df_AB_master['Revenue - Comulative Sum'] = df_AB_master['Revenue'].expanding().sum()

# %%
df_AB_master
# Out:
#    Shop ID Department           Shop Name Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#    Expensive  No of Employees  Shop Size (Square Ft)  Revenue - Comulative Sum
# 0     158501              113                   1336                  288182.0
# 1      61779              101                   1137                  442629.0
# 2     241889               72                   1120                  957285.0
# 3     529249              115                   2124                 1885792.0
# 4      95443              152                   1843                 2088861.0
# 5      97173              124                   1269                 2331792.0
# 6     460019              155                   2448                 3153253.0
# 7     145210              121                   2323                 3490949.0

# %%
#with this method, you can calculate comulative mean
df_AB_master['Revenue - Comulative Mean'] = df_AB_master['Revenue'].expanding().mean()

# %%
df_AB_master
# Out:
#    Shop ID Department           Shop Name Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#    Expensive  No of Employees  Shop Size (Square Ft)  \
# 0     158501              113                   1336
# 1      61779              101                   1137
# 2     241889               72                   1120
# 3     529249              115                   2124
# 4      95443              152                   1843
# 5      97173              124                   1269
# 6     460019              155                   2448
# 7     145210              121                   2323
#
#    Revenue - Comulative Sum  Revenue - Comulative Mean
# 0                  288182.0              288182.000000
# 1                  442629.0              221314.500000
# 2                  957285.0              319095.000000
# 3                 1885792.0              471448.000000
# 4                 2088861.0              417772.200000
# 5                 2331792.0              388632.000000
# 6                 3153253.0              450464.714286
# 7                 3490949.0              436368.625000

# %%
df_AB_master['Revenue - Comulative Mean'] = round(df_AB_master['Revenue'].expanding().mean(),2)
df_AB_master
# Out:
#    Shop ID Department           Shop Name Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#    Expensive  No of Employees  Shop Size (Square Ft)  \
# 0     158501              113                   1336
# 1      61779              101                   1137
# 2     241889               72                   1120
# 3     529249              115                   2124
# 4      95443              152                   1843
# 5      97173              124                   1269
# 6     460019              155                   2448
# 7     145210              121                   2323
#
#    Revenue - Comulative Sum  Revenue - Comulative Mean
# 0                  288182.0                  288182.00
# 1                  442629.0                  221314.50
# 2                  957285.0                  319095.00
# 3                 1885792.0                  471448.00
# 4                 2088861.0                  417772.20
# 5                 2331792.0                  388632.00
# 6                 3153253.0                  450464.71
# 7                 3490949.0                  436368.62

# %%
df_AB_master.index+1
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
#with index attribute you can add row number to data frame
df_AB_master['Row Number'] = df_AB_master.index+1

# %%
df_AB_master
# Out:
#    Shop ID Department           Shop Name Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#    Expensive  No of Employees  Shop Size (Square Ft)  \
# 0     158501              113                   1336
# 1      61779              101                   1137
# 2     241889               72                   1120
# 3     529249              115                   2124
# 4      95443              152                   1843
# 5      97173              124                   1269
# 6     460019              155                   2448
# 7     145210              121                   2323
#
#    Revenue - Comulative Sum  Revenue - Comulative Mean  Row Number
# 0                  288182.0              288182.000000           1
# 1                  442629.0              221314.500000           2
# 2                  957285.0              319095.000000           3
# 3                 1885792.0              471448.000000           4
# 4                 2088861.0              417772.200000           5
# 5                 2331792.0              388632.000000           6
# 6                 3153253.0              450464.714286           7
# 7                 3490949.0              436368.625000           8

# %%
#if you want to ordering data based on rank, use rank() method
df_AB_master.rank()
# Out:
#    Shop ID  Department  Shop Name  Shop Region  Revenue  Profit  Expensive  \
# 0      1.5         2.5        1.5          3.5      4.0     3.0        5.0
# 1      1.5         6.5        1.5          3.5      1.0     1.0        1.0
# 2      3.5         2.5        3.5          1.5      6.0     6.0        6.0
# 3      3.5         6.5        3.5          1.5      8.0     8.0        8.0
# 4      5.5         2.5        7.5          5.5      2.0     2.0        2.0
# 5      5.5         6.5        7.5          5.5      3.0     4.0        3.0
# 6      7.5         2.5        5.5          7.5      7.0     7.0        7.0
# 7      7.5         6.5        5.5          7.5      5.0     5.0        4.0
#
#    No of Employees  Shop Size (Square Ft)  Revenue - Comulative Sum  \
# 0              3.0                    4.0                       1.0
# 1              2.0                    2.0                       2.0
# 2              1.0                    1.0                       3.0
# 3              4.0                    6.0                       4.0
# 4              7.0                    5.0                       5.0
# 5              6.0                    3.0                       6.0
# 6              8.0                    8.0                       7.0
# 7              5.0                    7.0                       8.0
#
#    Revenue - Comulative Mean  Row Number
# 0                        2.0         1.0
# 1                        1.0         2.0
# 2                        3.0         3.0
# 3                        8.0         4.0
# 4                        5.0         5.0
# 5                        4.0         6.0
# 6                        7.0         7.0
# 7                        6.0         8.0

# %%
df_AB_master['Revenue'].rank(ascending=True)
# Out:
# 0    4.0
# 1    1.0
# 2    6.0
# 3    8.0
# 4    2.0
# 5    3.0
# 6    7.0
# 7    5.0
# Name: Revenue, dtype: float64

# %%
df_AB_master['Rank - Revenue'] = df_AB_master['Revenue'].rank(ascending=False)

# %%
df_AB_master
# Out:
#    Shop ID Department           Shop Name Shop Region  Revenue  Profit  \
# 0     1001          A  Alpha Technologies       North   288182  129681
# 1     1001          B  Alpha Technologies       North   154447   92668
# 2     1002          A           Beta Shop        East   514656  272767
# 3     1002          B           Beta Shop        East   928507  399258
# 4     1003          A          Gamma Mart       South   203069  107626
# 5     1003          B          Gamma Mart       South   242931  145758
# 6     1004          A       Delta and Co.        West   821461  361442
# 7     1004          B       Delta and Co.        West   337696  192486
#
#    Expensive  No of Employees  Shop Size (Square Ft)  \
# 0     158501              113                   1336
# 1      61779              101                   1137
# 2     241889               72                   1120
# 3     529249              115                   2124
# 4      95443              152                   1843
# 5      97173              124                   1269
# 6     460019              155                   2448
# 7     145210              121                   2323
#
#    Revenue - Comulative Sum  Revenue - Comulative Mean  Row Number  \
# 0                  288182.0              288182.000000           1
# 1                  442629.0              221314.500000           2
# 2                  957285.0              319095.000000           3
# 3                 1885792.0              471448.000000           4
# 4                 2088861.0              417772.200000           5
# 5                 2331792.0              388632.000000           6
# 6                 3153253.0              450464.714286           7
# 7                 3490949.0              436368.625000           8
#
#    Rank - Revenue
# 0             5.0
# 1             8.0
# 2             3.0
# 3             1.0
# 4             7.0
# 5             6.0
# 6             2.0
# 7             4.0

# %%
#A Pandas Series is like a column in a table.

#It is a one-dimensional array holding data of any type.
a = [1,5,7]
my_series = pd.Series(a)
my_series
# Out:
# 0    1
# 1    5
# 2    7
# dtype: int64

# %%
print(my_series[1])
# Out:
# 5

# %%
#With the index argument, you can name your own labels.
my_series = pd.Series(a,index = ['x','y','z'])
print(my_series['y'])
# Out:
# 5

# %%
#You can also use a key/value object, like a dictionary, when creating a Series.
calories = {"day1": 420, "day2": 380, "day3": 390}
my_series = pd.Series(calories)
print(my_series['day1'])
# Out:
# 420

# %%
#Big data sets are often stored, or extracted as JSON.

#JSON is plain text, but has the format of an object, 
#and is well known in the world of programming, including Pandas.
#JSON objects have the same format as Python dictionaries.

df_jason = pd.read_json('D:\data.js')

# %%
df_jason
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#There is also a tail() method for viewing the last rows of the DataFrame.

#The tail() method returns the headers and a specified number of rows, starting from the bottom.
df_jason.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df_jason.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.6 KB

# %%
df_dirty = pd.read_csv('F:\Document\PythonCode\dirtydata.csv')

# %%
df_dirty.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
#Empty cells can potentially give you a wrong result when you analyze data.
#One way to deal with empty cells is to remove rows that contain empty cells.
new_df = df_dirty.dropna()
#the dropna() method returns a new DataFrame, and will not change the original.
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  29 non-null     int64
#  1   Date      29 non-null     object
#  2   Pulse     29 non-null     int64
#  3   Maxpulse  29 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
temp_df_dirty = df_dirty
temp_df_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
#Now, the dropna(inplace = True) will NOT return a new DataFrame, 
#but it will remove all rows containg NULL values from the original DataFrame.
temp_df_dirty.dropna(inplace = True)
temp_df_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  29 non-null     int64
#  1   Date      29 non-null     object
#  2   Pulse     29 non-null     int64
#  3   Maxpulse  29 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df_dirty['Date']
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 23    '2020/12/23'
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26        20201226
# 27    '2020/12/27'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# Name: Date, dtype: object

# %%
#for fix the wrong format of date, use to_datetime method
df_dirty['Date'] = pd.to_datetime(df_dirty['Date'])
df_dirty['Date']
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %%
df_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  29 non-null     int64
#  1   Date      29 non-null     datetime64[ns]
#  2   Pulse     29 non-null     int64
#  3   Maxpulse  29 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB

# %%
for x in df_dirty.index:
    if df_dirty.loc[x,'Duration']>120:
        df_dirty.loc[x,'Duration'] = 120

# %%
df_dirty['Duration']
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
# 5      60
# 6      60
# 7     120
# 8      30
# 9      60
# 10     60
# 11     60
# 12     60
# 13     60
# 14     60
# 15     60
# 16     60
# 17     60
# 19     60
# 20     45
# 21     60
# 23     60
# 24     45
# 25     60
# 26     60
# 27     60
# 29     60
# 30     60
# 31     60
# Name: Duration, dtype: int64

# %%
for x in df_dirty.index:
    if df_dirty.loc[x,'Duration']>=120:
        df_dirty.loc[x,'Duration'] = (df_dirty['Duration'].mean())

# %%
df_dirty['Duration']
# Out:
# 0     60.000000
# 1     60.000000
# 2     60.000000
# 3     45.000000
# 4     45.000000
# 5     60.000000
# 6     60.000000
# 7     58.965517
# 8     30.000000
# 9     60.000000
# 10    60.000000
# 11    60.000000
# 12    60.000000
# 13    60.000000
# 14    60.000000
# 15    60.000000
# 16    60.000000
# 17    60.000000
# 19    60.000000
# 20    45.000000
# 21    60.000000
# 23    60.000000
# 24    45.000000
# 25    60.000000
# 26    60.000000
# 27    60.000000
# 29    60.000000
# 30    60.000000
# 31    60.000000
# Name: Duration, dtype: float64

# %%
#A great aspect of the Pandas module is the corr() method.

#The corr() method calculates the relationship between each column in your data set.
#The corr() method ignores "not numeric" columns.
df_dirty.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.199935 -0.391199  0.291992
# Pulse    -0.199935  1.000000  0.211055  0.510361
# Maxpulse -0.391199  0.211055  1.000000  0.352529
# Calories  0.291992  0.510361  0.352529  1.000000

# %%
#Pandas uses the plot() method to create diagrams.
df_dirty.plot()
# Out:
# <AxesSubplot:>

# %%
df_dirty.plot(kind='scatter',x = 'Duration', y = 'Calories')
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Calories'>

# %%
#Use the kind argument to specify that you want a histogram
df_dirty['Duration'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
