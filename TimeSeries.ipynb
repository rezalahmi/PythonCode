# %%
import pandas as pd

# %%
df = pd.read_csv(r'temp.csv')

# %%
df.head()
# Out:
#               datetime    LA   NY
# 0  2013-01-01 00:00:00  11.7 -1.1
# 1  2013-01-01 01:00:00  10.7 -1.7
# 2  2013-01-01 02:00:00   9.9 -2.0
# 3  2013-01-01 03:00:00   9.3 -2.1
# 4  2013-01-01 04:00:00   8.8 -2.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35064 non-null  object
#  1   LA        35062 non-null  float64
#  2   NY        35064 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 821.9+ KB

# %%
df.datetime
# Out:
# 0        2013-01-01 00:00:00
# 1        2013-01-01 01:00:00
# 2        2013-01-01 02:00:00
# 3        2013-01-01 03:00:00
# 4        2013-01-01 04:00:00
#                 ...
# 35059    2016-12-31 19:00:00
# 35060    2016-12-31 20:00:00
# 35061    2016-12-31 21:00:00
# 35062    2016-12-31 22:00:00
# 35063    2016-12-31 23:00:00
# Name: datetime, Length: 35064, dtype: object

# %%
df.datetime[0]
# Out:
# '2013-01-01 00:00:00'

# %%
pd.to_datetime(df.datetime)
# Out:
# 0       2013-01-01 00:00:00
# 1       2013-01-01 01:00:00
# 2       2013-01-01 02:00:00
# 3       2013-01-01 03:00:00
# 4       2013-01-01 04:00:00
#                 ...
# 35059   2016-12-31 19:00:00
# 35060   2016-12-31 20:00:00
# 35061   2016-12-31 21:00:00
# 35062   2016-12-31 22:00:00
# 35063   2016-12-31 23:00:00
# Name: datetime, Length: 35064, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35064 non-null  object
#  1   LA        35062 non-null  float64
#  2   NY        35064 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 821.9+ KB

# %%
df.datetime[0]
# Out:
# '2013-01-01 00:00:00'

# %%
df.set_index(df.datetime)
# Out:
#                                 datetime    LA   NY
# datetime
# 2013-01-01 00:00:00  2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00  2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00  2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00  2013-01-01 04:00:00   8.8 -2.3
# ...                                  ...   ...  ...
# 2016-12-31 19:00:00  2016-12-31 19:00:00  13.5  4.6
# 2016-12-31 20:00:00  2016-12-31 20:00:00  13.2  5.7
# 2016-12-31 21:00:00  2016-12-31 21:00:00  12.8  5.8
# 2016-12-31 22:00:00  2016-12-31 22:00:00  12.3  5.7
# 2016-12-31 23:00:00  2016-12-31 23:00:00  11.9  5.5
#
# [35064 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35064 non-null  object
#  1   LA        35062 non-null  float64
#  2   NY        35064 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 821.9+ KB

# %%
temp = df.set_index(pd.to_datetime(df.datetime)).drop('datetime',axis=1)

# %%
temp.head()
# Out:
#                        LA   NY
# datetime
# 2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00   8.8 -2.3

# %%
temp.index
# Out:
# DatetimeIndex(['2013-01-01 00:00:00', '2013-01-01 01:00:00',
#                '2013-01-01 02:00:00', '2013-01-01 03:00:00',
#                '2013-01-01 04:00:00', '2013-01-01 05:00:00',
#                '2013-01-01 06:00:00', '2013-01-01 07:00:00',
#                '2013-01-01 08:00:00', '2013-01-01 09:00:00',
#                ...
#                '2016-12-31 14:00:00', '2016-12-31 15:00:00',
#                '2016-12-31 16:00:00', '2016-12-31 17:00:00',
#                '2016-12-31 18:00:00', '2016-12-31 19:00:00',
#                '2016-12-31 20:00:00', '2016-12-31 21:00:00',
#                '2016-12-31 22:00:00', '2016-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=35064, freq=None)

# %%
temp.index[0]
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
temp.describe()
# Out:
#                  LA            NY
# count  35062.000000  35064.000000
# mean      17.486016     12.068269
# std        6.640666     10.466832
# min       -6.600000    -22.400000
# 25%       12.900000      3.900000
# 50%       17.200000     12.500000
# 75%       21.900000     20.600000
# max       42.300000     37.100000

# %%
temp.LA.value_counts()
# Out:
#  16.2    238
#  16.7    237
#  15.2    234
#  18.2    231
#  16.6    228
#         ...
# -2.0       1
# -2.2       1
# -5.9       1
#  37.6      1
# -4.2       1
# Name: LA, Length: 442, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
temp.plot(figsize=(12,8))
plt.show()

# %%
temp.plot(figsize=(15,8),subplots=True)
plt.show()

# %%
temp.plot(figsize=(15,8),subplots=True,layout=(1,2))
plt.show()

# %%
temp.plot(figsize=(15,8),subplots=True,layout=(1,2),sharey=True)
plt.show()

# %%
temp.loc['2015']
# Out:
#                        LA   NY
# datetime
# 2015-01-01 00:00:00   3.8 -5.1
# 2015-01-01 01:00:00   4.4 -5.1
# 2015-01-01 02:00:00   3.2 -6.0
# 2015-01-01 03:00:00   1.2 -6.0
# 2015-01-01 04:00:00   0.2 -6.0
# ...                   ...  ...
# 2015-12-31 19:00:00  16.0  8.1
# 2015-12-31 20:00:00  16.0  8.1
# 2015-12-31 21:00:00  16.4  7.9
# 2015-12-31 22:00:00  16.6  7.2
# 2015-12-31 23:00:00  16.8  6.2
#
# [8760 rows x 2 columns]

# %%
temp.loc['2015-12']
# Out:
#                        LA   NY
# datetime
# 2015-12-01 00:00:00  18.6  5.8
# 2015-12-01 01:00:00  17.4  5.2
# 2015-12-01 02:00:00  15.5  5.1
# 2015-12-01 03:00:00  14.4  5.3
# 2015-12-01 04:00:00  12.6  5.3
# ...                   ...  ...
# 2015-12-31 19:00:00  16.0  8.1
# 2015-12-31 20:00:00  16.0  8.1
# 2015-12-31 21:00:00  16.4  7.9
# 2015-12-31 22:00:00  16.6  7.2
# 2015-12-31 23:00:00  16.8  6.2
#
# [744 rows x 2 columns]

# %%
temp.loc['2015-1':'2015-2']
# Out:
#                        LA    NY
# datetime
# 2015-01-01 00:00:00   3.8  -5.1
# 2015-01-01 01:00:00   4.4  -5.1
# 2015-01-01 02:00:00   3.2  -6.0
# 2015-01-01 03:00:00   1.2  -6.0
# 2015-01-01 04:00:00   0.2  -6.0
# ...                   ...   ...
# 2015-02-28 19:00:00  11.5  -6.0
# 2015-02-28 20:00:00  11.8  -4.7
# 2015-02-28 21:00:00  10.5  -4.7
# 2015-02-28 22:00:00  11.3  -4.7
# 2015-02-28 23:00:00  10.5 -11.5
#
# [1416 rows x 2 columns]

# %%
temp.loc['2016':]
# Out:
#                        LA   NY
# datetime
# 2016-01-01 00:00:00  15.9  6.4
# 2016-01-01 01:00:00  15.0  6.3
# 2016-01-01 02:00:00   8.4  5.9
# 2016-01-01 03:00:00  11.1  5.7
# 2016-01-01 04:00:00  10.7  5.2
# ...                   ...  ...
# 2016-12-31 19:00:00  13.5  4.6
# 2016-12-31 20:00:00  13.2  5.7
# 2016-12-31 21:00:00  12.8  5.8
# 2016-12-31 22:00:00  12.3  5.7
# 2016-12-31 23:00:00  11.9  5.5
#
# [8784 rows x 2 columns]

# %%
two_day = pd.to_datetime(['2015-05-1','2016-05-1'])

# %%
two_day
# Out:
# DatetimeIndex(['2015-05-01', '2016-05-01'], dtype='datetime64[ns]', freq=None)

# %%
temp.loc[two_day]
# Out:
#               LA    NY
# 2015-05-01  25.5  13.9
# 2016-05-01  19.7  13.1

# %%
temp = pd.read_csv(r'temp.csv',parse_dates=['datetime'],index_col='datetime')

# %%
temp.head()
# Out:
#                        LA   NY
# datetime
# 2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00   8.8 -2.3

# %%
temp.resample('D')

# %%
temp.resample('D').first()
# Out:
#               LA    NY
# datetime
# 2013-01-01  11.7  -1.1
# 2013-01-02  13.2   2.6
# 2013-01-03  15.1   0.3
# 2013-01-04  16.3  -1.2
# 2013-01-05  18.1  -1.2
# ...          ...   ...
# 2016-12-27  15.1   4.1
# 2016-12-28  19.9  11.2
# 2016-12-29  23.3   2.1
# 2016-12-30  25.5   3.0
# 2016-12-31  15.7   0.8
#
# [1461 rows x 2 columns]

# %%
temp.resample('D').last()
# Out:
#               LA    NY
# datetime
# 2013-01-01  14.0   2.7
# 2013-01-02  15.1   1.2
# 2013-01-03  16.6  -1.5
# 2013-01-04  20.0  -1.2
# 2013-01-05  17.8   2.0
# ...          ...   ...
# 2016-12-27  20.1  12.9
# 2016-12-28  24.3   2.6
# 2016-12-29  25.6   4.2
# 2016-12-30  15.9   1.2
# 2016-12-31  11.9   5.5
#
# [1461 rows x 2 columns]

# %%
list(temp.resample('D'))[1]
# Out:
# (Timestamp('2013-01-02 00:00:00', freq='D'),
#                         LA   NY
#  datetime
#  2013-01-02 00:00:00  13.2  2.6
#  2013-01-02 01:00:00  11.8  2.7
#  2013-01-02 02:00:00  10.5  2.9
#  2013-01-02 03:00:00   9.5  2.9
#  2013-01-02 04:00:00   8.3  2.9
#  2013-01-02 05:00:00   8.0  3.5
#  2013-01-02 06:00:00   7.5  3.7
#  2013-01-02 07:00:00   7.1  3.5
#  2013-01-02 08:00:00   6.4  3.7
#  2013-01-02 09:00:00   6.0  3.6
#  2013-01-02 10:00:00   5.9  3.5
#  2013-01-02 11:00:00   6.1  3.6
#  2013-01-02 12:00:00   5.8  3.5
#  2013-01-02 13:00:00   5.6  3.5
#  2013-01-02 14:00:00   5.8  3.7
#  2013-01-02 15:00:00   5.9  4.0
#  2013-01-02 16:00:00   6.4  4.0
#  2013-01-02 17:00:00   9.0  3.6
#  2013-01-02 18:00:00  11.5  3.1
#  2013-01-02 19:00:00  13.3  3.2
#  2013-01-02 20:00:00  14.2  3.2
#  2013-01-02 21:00:00  15.0  2.9
#  2013-01-02 22:00:00  14.9  2.0
#  2013-01-02 23:00:00  15.1  1.2)

# %%
list(temp.resample('D'))[1][0]
# Out:
# Timestamp('2013-01-02 00:00:00', freq='D')

# %%
list(temp.resample('M'))[13]
# Out:
# (Timestamp('2014-02-28 00:00:00', freq='M'),
#                         LA   NY
#  datetime
#  2014-02-01 00:00:00  15.3  1.7
#  2014-02-01 01:00:00  14.6  0.9
#  2014-02-01 02:00:00  13.7 -0.0
#  2014-02-01 03:00:00  13.5 -0.1
#  2014-02-01 04:00:00  13.1  0.0
#  ...                   ...  ...
#  2014-02-28 19:00:00  12.8 -6.5
#  2014-02-28 20:00:00  13.9 -5.7
#  2014-02-28 21:00:00  14.5 -4.7
#  2014-02-28 22:00:00  13.7 -5.3
#  2014-02-28 23:00:00  12.8 -6.2
#
#  [672 rows x 2 columns])

# %%
temp.resample('Y').first()
# Out:
#               LA   NY
# datetime
# 2013-12-31  11.7 -1.1
# 2014-12-31  18.8 -1.2
# 2015-12-31   3.8 -5.1
# 2016-12-31  15.9  6.4

# %%
temp.resample('Y').last()
# Out:
#               LA   NY
# datetime
# 2013-12-31  20.8 -0.9
# 2014-12-31   5.6 -4.5
# 2015-12-31  16.8  6.2
# 2016-12-31  11.9  5.5

# %%
temp.resample('Y').mean()
# Out:
#                    LA         NY
# datetime
# 2013-12-31  17.174229  12.196153
# 2014-12-31  17.245616  11.370959
# 2015-12-31  17.191530  11.795194
# 2016-12-31  18.330305  12.908470

# %%
temp.resample('Y').max()
# Out:
#               LA    NY
# datetime
# 2013-12-31  38.8  37.1
# 2014-12-31  37.1  33.7
# 2015-12-31  36.8  34.1
# 2016-12-31  42.3  35.2

# %%
temp.resample('Y').min()
# Out:
#              LA    NY
# datetime
# 2013-12-31 -4.0 -11.9
# 2014-12-31 -4.9 -15.9
# 2015-12-31 -6.6 -22.4
# 2016-12-31 -3.3 -18.1

# %%
temp.resample('M').max()
# Out:
#               LA    NY
# datetime
# 2013-01-31  25.5  13.1
# 2013-02-28  26.3  12.6
# 2013-03-31  27.6  14.2
# 2013-04-30  27.9  27.9
# 2013-05-31  32.6  32.8
# 2013-06-30  32.4  33.9
# 2013-07-31  37.5  37.1
# 2013-08-31  36.7  31.6
# 2013-09-30  38.8  33.8
# 2013-10-31  33.2  28.6
# 2013-11-30  32.0  20.7
# 2013-12-31  28.0  19.7
# 2014-01-31  28.2  13.6
# 2014-02-28  25.5  11.5
# 2014-03-31  30.3  17.7
# 2014-04-30  30.7  25.1
# 2014-05-31  37.1  30.1
# 2014-06-30  29.6  31.7
# 2014-07-31  33.4  33.7
# 2014-08-31  31.9  31.2
# 2014-09-30  33.6  31.9
# 2014-10-31  33.0  24.4
# 2014-11-30  28.5  20.6
# 2014-12-31  20.2  16.5
# 2015-01-31  23.5  11.2
# 2015-02-28  25.9   6.3
# 2015-03-31  29.2  12.5
# 2015-04-30  29.7  22.8
# 2015-05-31  28.5  29.1
# 2015-06-30  33.2  33.5
# 2015-07-31  31.2  33.5
# 2015-08-31  36.7  32.9
# 2015-09-30  36.7  34.1
# 2015-10-31  36.8  23.6
# 2015-11-30  29.9  22.9
# 2015-12-31  25.7  20.7
# 2016-01-31  23.8  15.6
# 2016-02-29  31.0  16.5
# ...

# %%
temp.resample('Q').max()
# Out:
#               LA    NY
# datetime
# 2013-03-31  27.6  14.2
# 2013-06-30  32.6  33.9
# 2013-09-30  38.8  37.1
# 2013-12-31  33.2  28.6
# 2014-03-31  30.3  17.7
# 2014-06-30  37.1  31.7
# 2014-09-30  33.6  33.7
# 2014-12-31  33.0  24.4
# 2015-03-31  29.2  12.5
# 2015-06-30  33.2  33.5
# 2015-09-30  36.7  34.1
# 2015-12-31  36.8  23.6
# 2016-03-31  31.0  24.8
# 2016-06-30  42.3  31.8
# 2016-09-30  37.6  35.2
# 2016-12-31  33.7  25.8

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.64-py2.py3-none-any.whl size=24095 sha256=2511addeb521065ab1efae57e99b1c510ebbb14b949ab8baf984c6256d79fc71
#   Stored in directory: c:\users\fourr\appdata\local\pip\cache\wheels\f9\e9\7e\8b13db3bf3aeb5049d759e10702736fb96753089ac950fddc0
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=1601ece38a821f61f3914964fb5efb0b91f878f6057d1955d69e71c06a631ead
#   Stored in directory: c:\users\fourr\appdata\local\pip\cache\wheels\57\6d\a3\a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# ...
