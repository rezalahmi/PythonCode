# %%
import pandas as pd
import seaborn as sns; sns.set()

# %%
df_salary = pd.read_csv(r'D:\Udemy\Udemy - The Python Bootcamp Data Science, Analytics & Visualisation\9. Data Visualisation - Seaborn\1.1 Salary.csv')
df_salary.head()
# Out:
#      Position  Years at Firm  Base Salary  Bonus  Predicted Score
# 0   Associate              2        33000   4290                6
# 1   Associate              1        28000   2240               15
# 2  Management              7        73000  23360               22
# 3   Associate              4        48500  10670               23
# 4   Associate              4        52000  11440               29

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Position         53 non-null     object
#  1   Years at Firm    53 non-null     int64
#  2   Base Salary      53 non-null     int64
#  3   Bonus            53 non-null     int64
#  4   Predicted Score  53 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.2+ KB

# %%
df_salary.describe()
# Out:
#        Years at Firm    Base Salary         Bonus  Predicted Score
# count      53.000000      53.000000     53.000000        53.000000
# mean        4.622642   55018.867925  17078.490566        54.000000
# std         3.558448   24631.898148  17832.914350        18.273562
# min         1.000000   27000.000000   2160.000000         6.000000
# 25%         2.000000   32500.000000   4160.000000        45.000000
# 50%         3.000000   49500.000000   9500.000000        55.000000
# 75%         6.000000   70000.000000  23200.000000        66.000000
# max        14.000000  119000.000000  80000.000000        98.000000

# %%
#seaborn.scatterplot
sns.scatterplot(x=df_salary['Years at Firm'],y=df_salary['Base Salary'])
# Out:
# <AxesSubplot:xlabel='Years at Firm', ylabel='Base Salary'>

# %%
sns.scatterplot(x=df_salary['Years at Firm'],y=df_salary['Base Salary'],hue=df_salary['Position'])
#hue:Grouping variable that will produce points with different colors. 
#Can be either categorical or numeric, 
#although color mapping will behave differently in latter case.
# Out:
# <AxesSubplot:xlabel='Years at Firm', ylabel='Base Salary'>

# %%
#data:Input data structure. 
#Either a long-form collection of vectors that can be assigned to named variables or 
#a wide-form dataset that will be internally reshaped.
sns.scatterplot(x='Years at Firm',y='Base Salary',data=df_salary)
# Out:
# <AxesSubplot:xlabel='Years at Firm', ylabel='Base Salary'>

# %%
#seaborn.lmplot
sns.lmplot(x='Years at Firm',y='Base Salary',data=df_salary)

# %%
sns.lmplot(x='Years at Firm',y='Base Salary',data=df_salary,hue='Position')

# %%
#seaborn.distplot
sns.distplot(df_salary['Predicted Score'],bins=10)
#bin:Specification of hist bins. 
#If unspecified, as reference rule is used that tries to find a useful default.
# Out:
# C:\Users\FourR\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Predicted Score', ylabel='Density'>

# %%
#hist:Whether to plot a (normed) histogram.
#kde:Whether to plot a gaussian kernel density estimate
sns.distplot(df_salary['Predicted Score'],bins=10,hist=False,kde=True)
# Out:
# C:\Users\FourR\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Predicted Score', ylabel='Density'>

# %%
#seaborn.kdeplot
sns.kdeplot(df_salary['Predicted Score'],shade=True)
#shade:Alias for fill. Using fill is recommended.
# Out:
# <AxesSubplot:xlabel='Predicted Score', ylabel='Density'>

# %%
sns.kdeplot(df_salary['Predicted Score'],shade=False)
# Out:
# <AxesSubplot:xlabel='Predicted Score', ylabel='Density'>
